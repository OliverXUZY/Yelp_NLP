# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
dir = os.path.join('drive','My Drive','Colab Notebooks','STAT628_module3')
dir
# Out:
# 'drive/My Drive/Colab Notebooks/STAT628_module3'

# %% [markdown]
# ## Import package and dataset

# %%
import numpy as np
import pandas as pd
import json
import string
import re

# %%
merged = pd.read_csv(os.path.join(dir,'dataset','merged.csv'))
merged.head()
# len(merged)
# Out:
#    Unnamed: 0  ...                 date
# 0           0  ...  2017-08-17 05:35:35
# 1           1  ...  2016-09-30 23:29:28
# 2           2  ...  2013-08-19 11:19:45
# 3           3  ...  2016-06-15 14:36:24
# 4           4  ...  2017-06-16 18:35:13
#
# [5 rows x 22 columns]

# %%
text = pd.read_csv(os.path.join(dir,'dataset','inte.csv'))
text.head()
# Out:
#                                                 text  stars
# 0  ['time', 'go', 'hair', 'icecream', 'break', 'g...    3.0
# 1  ['pretty', 'good', 'froyo', 'place', 'topping'...    5.0
# 2  ['love', 'place', ' ', 'freeze', 'yogurt', 'go...    5.0
# 3  ['freeze', 'yogurt', 'come', 'bubble', 'tea', ...    5.0
# 4  ['love', 'place', '!', 'amaze', 'freeze', 'yog...    5.0

# %%
business_id = merged['business_id'].tolist()

# %%
text['business_id'] = merged['business_id']

# %%
text.head()
# Out:
#                                                 text  ...             business_id
# 0  ['time', 'go', 'hair', 'icecream', 'break', 'g...  ...  irft4YkdNsww4DNf_Aftew
# 1  ['pretty', 'good', 'froyo', 'place', 'topping'...  ...  irft4YkdNsww4DNf_Aftew
# 2  ['love', 'place', ' ', 'freeze', 'yogurt', 'go...  ...  irft4YkdNsww4DNf_Aftew
# 3  ['freeze', 'yogurt', 'come', 'bubble', 'tea', ...  ...  irft4YkdNsww4DNf_Aftew
# 4  ['love', 'place', '!', 'amaze', 'freeze', 'yog...  ...  irft4YkdNsww4DNf_Aftew
#
# [5 rows x 3 columns]

# %% [markdown]
# ## Extra Cleanning on review texts

# %%
review_text = text.loc[:,'text'].tolist()

# %%
remove = string.punctuation
remove = remove.replace(',','')
def convert_data(data):
  data = re.sub("[{}]+".format(remove), '',data)
  data = re.sub(' +',",",data)
  data = data.split(',')
  return data

# %%
# convert_data(review_text[2])

# %%
review = []
for i in range(len(text)):
  review.append(convert_data(review_text[i]))

# %%
# review[2]

# %% [markdown]
# ## Import Positive and Negative Words

# %%
neg_word = pd.read_csv(os.path.join(dir,"negative_words.txt"),header=None,names=['word'])
neg_word = neg_word.loc[:,'word'].values.tolist()
print(neg_word)
# Out:
# ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted', 'aborts', 'abrade', 'abrasive', 'abrupt', 'abruptly', 'abscond', 'absence', 'absent-minded', 'absentee', 'absurd', 'absurdity', 'absurdly', 'absurdness', 'abuse', 'abused', 'abuses', 'abusive', 'abysmal', 'abysmally', 'abyss', 'accidental', 'accost', 'accursed', 'accusation', 'accusations', 'accuse', 'accuses', 'accusing', 'accusingly', 'acerbate', 'acerbic', 'acerbically', 'ache', 'ached', 'aches', 'achey', 'aching', 'acrid', 'acridly', 'acridness', 'acrimonious', 'acrimoniously', 'acrimony', 'adamant', 'adamantly', 'addict', 'addicted', 'addicting', 'addicts', 'admonish', 'admonisher', 'admonishingly', 'admonishment', 'admonition', 'adulterate', 'adulterated', 'adulteration', 'adulterier', 'adversarial', 'adversary', 'adverse', 'adversity', 'afflict', 'affliction', 'afflictive', 'affront', 'afraid', 'aggravate', 'aggravating', 'aggravation', 'aggression', 'aggre
# ...

# %%
pos_word = pd.read_csv(os.path.join(dir,"positive_words.txt"),header=None,names=['word'])
pos_word = pos_word.loc[:,'word'].values.tolist()
print(pos_word)
# Out:
# ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation', 'accolade', 'accolades', 'accommodative', 'accomodative', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', 'accurate', 'accurately', 'achievable', 'achievement', 'achievements', 'achievible', 'acumen', 'adaptable', 'adaptive', 'adequate', 'adjustable', 'admirable', 'admirably', 'admiration', 'admire', 'admirer', 'admiring', 'admiringly', 'adorable', 'adore', 'adored', 'adorer', 'adoring', 'adoringly', 'adroit', 'adroitly', 'adulate', 'adulation', 'adulatory', 'advanced', 'advantage', 'advantageous', 'advantageously', 'advantages', 'adventuresome', 'adventurous', 'advocate', 'advocated', 'advocates', 'affability', 'affable', 'affably', 'affectation', 'affection', 'affectionate', 'affinity', 'affirm', 'affirmation', 'affirmative', 'affluence', 'affluent', 'afford', 'affordable', 'affordably', 'afordable', 'agile', 'agilely', 'agility', 'agreeable', '
# ...

# %%
text['text'] = review

# %%
text.head()
# Out:
#                                                 text  ...             business_id
# 0  [time, go, hair, icecream, break, glass, grind...  ...  irft4YkdNsww4DNf_Aftew
# 1  [pretty, good, froyo, place, topping, bubble, ...  ...  irft4YkdNsww4DNf_Aftew
# 2  [love, place, freeze, yogurt, good, week, shop...  ...  irft4YkdNsww4DNf_Aftew
# 3  [freeze, yogurt, come, bubble, tea, lot, bubbl...  ...  irft4YkdNsww4DNf_Aftew
# 4  [love, place, amaze, freeze, yogurt, great, bu...  ...  irft4YkdNsww4DNf_Aftew
#
# [5 rows x 3 columns]

# %%
business_id = list(text.business_id.unique())

# %%
def find_adjacent(noun, review):
  pos_label = [99999]
  neg_label = [99999]
  noun_label = []
  count = 0
  for index, word in enumerate(review):
    if word in pos_word:
      pos_label.append(index)
    if word in neg_word:
      neg_label.append(index)
    if noun == word:
      noun_label.append(index)
  for index in noun_label:
    if min(abs(np.array(pos_label)-index)) < min(abs(np.array(neg_label)-index)):
      count += 1
  return np.array((count,len(noun_label)-count))

# %%
def pos_neg_count(noun, review):
  count_result = []
  for word in noun:
    num = np.array((0,0))
    for i in range(len(review)):
      num += find_adjacent(word,review[i])
    count_result.append([word, num[0], num[1]])
  return pd.DataFrame(count_result,columns=['word','pos_num','neg_num'])

# %%
flavour = ['taste', 'flavour', 'topping','chocolate','strawberry','vanilla', 'mango', 'caramel', 'banana', 'coconut', 'raspberry']
price = ['price', 'combo', 'charge']
service = ['service', 'cashier', 'customer', 'owner', 'seat', 'table', 'employee', 'location', 'manager', 'drive', 'park', 'room', 'experience', 'atmosphere', 'street', 'staff', 'space', 'machine', 'decor']

# %%
def business_pos_neg_count(flavour, price, service, business_id):
  result = pd.DataFrame(columns = ['word','pos_num','neg_num','subject','business_id','review_num'])
  for id in business_id:
    temp = text.loc[text['business_id'] == id]
    flavour_result = pos_neg_count(flavour,temp['text'].tolist())
    flavour_result['subject'] = 'flavour'
    price_result = pos_neg_count(price,temp['text'].tolist())
    price_result['subject'] = 'price'
    service_result = pos_neg_count(service,temp['text'].tolist())
    service_result['subject'] = 'service'
    temp_result = pd.concat([flavour_result,price_result,service_result])
    temp_result['business_id'] = id
    temp_result['review_num'] = len(temp)
    result = pd.concat([result,temp_result])
  return result

# %%
result = business_pos_neg_count(flavour, price, service, business_id)

# %%
result.shape
# Out:
# (91212, 6)

# %%
result.to_csv(os.path.join(dir,'dataset','business_pos_neg.csv'),index = False)

# %% [markdown]
# ## Add attribute state

# %%
bus = pd.read_csv(os.path.join(dir,'dataset','business.csv'))
bus.head()
# Out:
#                           address  ... state
# 0     2818 E Camino Acequia Drive  ...    AZ
# 1            30 Eglinton Avenue W  ...    ON
# 2       10110 Johnston Rd, Ste 15  ...    NC
# 3   15655 W Roosevelt St, Ste 237  ...    AZ
# 4  4209 Stuart Andrew Blvd, Ste F  ...    NC
#
# [5 rows x 14 columns]

# %%
result = pd.read_csv(os.path.join(dir,'dataset','business_pos_neg.csv'))

# %%
state = bus[['business_id','state']]
state.head()
# Out:
#               business_id state
# 0  1SWheh84yJXfytovILXOAQ    AZ
# 1  QXAEGFB4oINsVuTFxEYKFQ    ON
# 2  gnKjwL_1w79qoiV3IC_xQQ    NC
# 3  xvX2CttrVhyG2z1dFg_0xw    AZ
# 4  HhyxOkGAM07SRYtlQ4wMFQ    NC

# %%
result = result.join(state.set_index('business_id'), on='business_id')
result.head()
# Out:
#          word  pos_num  neg_num  ...             business_id review_num  state
# 0       taste        1        0  ...  irft4YkdNsww4DNf_Aftew          6     NC
# 1     flavour        0        0  ...  irft4YkdNsww4DNf_Aftew          6     NC
# 2     topping        1        0  ...  irft4YkdNsww4DNf_Aftew          6     NC
# 3   chocolate        0        0  ...  irft4YkdNsww4DNf_Aftew          6     NC
# 4  strawberry        0        0  ...  irft4YkdNsww4DNf_Aftew          6     NC
#
# [5 rows x 7 columns]

# %%
result.to_csv(os.path.join(dir,'dataset','business_pos_neg.csv'),index = False)
